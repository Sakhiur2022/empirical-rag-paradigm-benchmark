# %% [markdown]
# ## Stratified Sampling for Query Generation (W1 / W2 / W3)
#
# Selects the source material for query generation: 50 chunks each for W1 (short factual), W2 (multi-hop), and W3 (semantic similarity), per category, per corpus type (abstracts and PDF chunks), across all 10 categories (yours and Sadman's).
#
# **Why not "start, middle, end of the file"**: this was the original framing, but positional sampling within a JSONL file samples whatever ordering the file happens to be in, which for this corpus is roughly arXiv ID order, i.e. roughly *submission date*. Sampling by file position would therefore sample by time period, not by topic, and could easily skew the query set toward, say, 2021-2022 papers or 2024-2025 papers depending on where "start/middle/end" thirds happen to fall, without that being visible or intended. This has nothing to do with representing the topical population, which was the actual goal.
#
# **Why stratified-by-cluster instead**: the BERTopic clustering already run for W3 ground truth gives each chunk a `bertopic_topic` label representing its actual sub-theme within the category. Sampling proportionally to cluster size (a cluster with 20% of a category's mass contributes ~20% of that category's sample) is a direct, defensible operationalization of "represents the entire population": the sample's topical composition mirrors the corpus's topical composition, rather than mirroring an arbitrary file ordering. This also reuses existing pipeline work rather than introducing a new, uncorrelated sampling mechanism.
#
# **Sample structure per category, per corpus type**:
# - W1 pool: 50 chunks, stratified by cluster, drawn independently
# - W2 pool: 50 chunk **pairs** (100 chunks total, but organized as 50 pairs), each pair drawn from either the same cluster or the nearest neighboring cluster (by centroid distance), stratified so pair-source-clusters are proportional to cluster size
# - W3 pool: 50 chunks, stratified by cluster, drawn independently
# - All three pools are drawn **independently** of each other (a chunk can appear in more than one pool by chance, this is accepted, not deduplicated across workload types, since each workload type needs its own representative sample of the population, not a partition of one shared sample)
#
# **Outliers (`bertopic_topic == -1`) are excluded from stratified sampling**: outlier points don't belong to any coherent sub-theme by BERTopic's own definition, so including them in a population-representative sample would be sampling noise, not population. They're reported separately (excluded count, percentage) for transparency, not silently dropped without a trace.

# %% [markdown]
# ### Install dependencies (Colab only, skip if already installed locally)

# %%
# Uncomment if running in Colab or a fresh environment
# !pip install huggingface_hub pandas numpy matplotlib -q

# %% [markdown]
# ### Configuration

# %%
import os

# --- Hugging Face repo (shared corpus) ---
REPO_ID = "Sakhiur/empirical-rag-paradigm-benchmark"
REPO_TYPE = "dataset"

# --- Which embeddings/clusters to sample against ---
EMBEDDING_MODEL = "text-embedding-3-small"

# --- All 10 categories ---
ALL_CATEGORIES = [
    "cs.AI", "cs.LG", "cs.IR", "cs.DB", "cs.SE",       # yours
    "cs.CV", "cs.CL", "cs.NE", "cs.DC", "cs.CR",       # collaborator's
]

# --- Sample sizes ---
N_PER_WORKLOAD = 50   # W1, W2 (pairs), W3 each get 50 per category per corpus type

# --- Reproducibility ---
RANDOM_STATE = 42

# --- Visualization settings, IEEE format ---
IEEE_COLUMN_WIDTH_INCHES = 3.5
IEEE_FULL_WIDTH_INCHES = 7.16
IEEE_FIGURE_DPI = 300

# --- Local paths ---
PROJECT_ROOT = ".."
SAMPLES_DIR = os.path.join(PROJECT_ROOT, "data", "query_samples", EMBEDDING_MODEL)
FIGURES_DIR = os.path.join(PROJECT_ROOT, "results", "figures", "sampling")
for corpus_type in ["abstracts", "pdf_chunks"]:
    for workload in ["w1", "w2", "w3"]:
        os.makedirs(os.path.join(SAMPLES_DIR, corpus_type, workload), exist_ok=True)
os.makedirs(FIGURES_DIR, exist_ok=True)

FORCE_RESAMPLE = True  # set True this run: the allocation function changed (floor guarantee added),
                        # so cached CSVs from the old pure-proportional allocator are stale and must be
                        # regenerated, not silently reused. Safe to set back to False after this run.

# %% [markdown]
# ### Authenticate with Hugging Face

# %%
from huggingface_hub import whoami, login

try:
    user_info = whoami()
    print(f"Authenticated as: {user_info['name']}")
except Exception:
    print("Not authenticated yet, prompting for token...")
    login()
    user_info = whoami()
    print(f"Authenticated as: {user_info['name']}")
# Out:
# Authenticated as: Sakhiur

# %% [markdown]
# ### Loader functions
#
# Joins three artifacts per (category, corpus_type): source records (for text), embeddings (for computing cluster centroids, needed for W2 adjacency), and BERTopic cluster assignments (for stratification). All three were produced by earlier notebooks in this pipeline and already live on the Hub.

# %%
import json
import numpy as np
from huggingface_hub import hf_hub_download


def load_source_records(category: str, corpus_type: str) -> dict[str, dict]:
    if corpus_type == "abstracts":
        repo_path = f"abstracts/by_category/{category}.jsonl"
    else:
        repo_path = f"pdf_chunks/{category}.jsonl"
    try:
        local_path = hf_hub_download(repo_id=REPO_ID, repo_type=REPO_TYPE, filename=repo_path)
    except Exception:
        return {}

    result = {}
    with open(local_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            record = json.loads(line)
            chunk_id = record["id"] if corpus_type == "abstracts" else f"{record['paper_id']}_p{record['page_num']}"
            result[chunk_id] = record
    return result


def load_embeddings(category: str, corpus_type: str) -> dict[str, list[float]]:
    repo_path = f"embeddings/{EMBEDDING_MODEL}/{corpus_type}/{category}.jsonl"
    try:
        local_path = hf_hub_download(repo_id=REPO_ID, repo_type=REPO_TYPE, filename=repo_path)
    except Exception:
        return {}

    result = {}
    with open(local_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            record = json.loads(line)
            result[record["chunk_id"]] = record["embedding"]
    return result


def load_bertopic_clusters(category: str, corpus_type: str) -> dict[str, int]:
    repo_path = f"bertopic/{EMBEDDING_MODEL}/{corpus_type}/{category}.jsonl"
    try:
        local_path = hf_hub_download(repo_id=REPO_ID, repo_type=REPO_TYPE, filename=repo_path)
    except Exception:
        return {}

    result = {}
    with open(local_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            record = json.loads(line)
            result[record["chunk_id"]] = record["bertopic_topic"]
    return result


def build_joined_table(category: str, corpus_type: str) -> dict:
    """
    Joins source records, embeddings, and cluster labels on chunk_id.
    Returns None if any of the three artifacts is missing (category not yet
    uploaded/processed, e.g. collaborator's categories before he runs the pipeline).
    Only chunk_ids present in all three are kept, since sampling needs all three
    pieces of information for every candidate chunk.
    """
    source = load_source_records(category, corpus_type)
    embeddings = load_embeddings(category, corpus_type)
    clusters = load_bertopic_clusters(category, corpus_type)

    if not source or not embeddings or not clusters:
        return None

    common_ids = set(source) & set(embeddings) & set(clusters)
    if not common_ids:
        return None

    return {
        "chunk_ids": sorted(common_ids),
        "source": {cid: source[cid] for cid in common_ids},
        "embeddings": {cid: np.array(embeddings[cid], dtype=np.float32) for cid in common_ids},
        "clusters": {cid: clusters[cid] for cid in common_ids},
    }

# %% [markdown]
# ### Stratified sampling function (W1 / W3, single-chunk pools)
#
# **Why proportional allocation, not equal allocation per cluster**: an alternative would be to take an equal number of samples from every cluster regardless of size (e.g. 5 from each of 10 clusters). This was rejected because it would systematically over-represent small, niche clusters and under-represent large, common sub-themes, which contradicts "represent the entire population." Proportional allocation (cluster with 20% of the category's mass gets ~20% of the 50 samples) is the standard definition of stratified sampling for population representativeness.
#
# **Minimum-floor allocation, added after diagnosing high TVD on large categories**: pure proportional allocation broke down on categories with many clusters relative to the sample budget (e.g. cs.CL abstracts: 204 clusters competing for 50 samples). Most clusters' exact proportional share (e.g. 0.2 or 0.3) floors to zero, so the vast majority of a category's sub-themes never appear in the sample at all, this was confirmed directly via a diagnostic showing 190 of cs.CL's 204 clusters rounding to zero allocation. To fix this without abandoning proportionality, every eligible cluster (`min_cluster_size_for_floor` or larger) is now guaranteed at least `MIN_SAMPLES_PER_CLUSTER` sample(s) before the remaining budget is allocated proportionally across all clusters by their remaining (post-floor) share. If the floor guarantee alone would exceed the total budget (more eligible clusters than n_total), the floor step falls back to prioritizing the largest clusters first, since guaranteeing literally every one of 204 clusters at least 1 sample is impossible within a 50-sample budget, some coverage tradeoff is unavoidable at that scale, and this makes it an explicit, principled tradeoff (largest, most substantial clusters guaranteed first) rather than an implicit one (whatever cluster happens to sort first in a dict).
#
# **Interaction with the BERTopic notebook fix**: this allocation fix is a safety net, not a substitute for the BERTopic notebook's `min_cluster_size` now being scaled by category population (see that notebook's config cell). Reducing cluster count at the source (fewer, larger, more substantial clusters) is the more direct fix; this allocation logic makes whatever cluster count remains behave better under a fixed sample budget, the two fixes are complementary, not redundant.
#
# **Rounding for the proportional remainder**: same largest-remainder rounding as before, applied to the remaining budget after floors are subtracted, so the total still sums exactly to n_total (or less, if the population itself has fewer than n_total points).

# %%
MIN_SAMPLES_PER_CLUSTER = 1   # every eligible cluster gets at least this many samples before
                               # proportional allocation runs on the remaining budget


def compute_proportional_allocation(cluster_sizes: dict[int, int], n_total: int, min_per_cluster: int = MIN_SAMPLES_PER_CLUSTER) -> dict[int, int]:
    """
    Given {cluster_id: size} and a total sample budget, returns {cluster_id: n_to_sample}.

    Two-stage allocation:
    1. Floor guarantee: every cluster gets min_per_cluster samples, largest clusters
       prioritized first if the floor guarantee alone would exceed n_total (i.e. more
       clusters than budget allows even at 1 each).
    2. Proportional remainder: whatever budget is left after floors is distributed
       proportionally to cluster size, using largest-remainder rounding so the total
       always sums exactly to n_total (or the full population, if smaller than n_total).
    """
    population_size = sum(cluster_sizes.values())
    if population_size <= n_total:
        return dict(cluster_sizes)  # take everything, population is smaller than the target sample

    # --- Stage 1: floor guarantee ---
    clusters_by_size_desc = sorted(cluster_sizes.keys(), key=lambda cid: cluster_sizes[cid], reverse=True)

    floor_allocation = {cid: 0 for cid in cluster_sizes}
    budget_remaining = n_total
    for cid in clusters_by_size_desc:
        if budget_remaining <= 0:
            break
        grant = min(min_per_cluster, cluster_sizes[cid], budget_remaining)
        floor_allocation[cid] = grant
        budget_remaining -= grant

    if budget_remaining <= 0:
        # floor guarantee alone consumed the whole budget (more clusters than n_total
        # allows even at 1 each); largest clusters were prioritized above, so this is
        # the best achievable coverage under a hard budget constraint
        return floor_allocation

    # --- Stage 2: proportional allocation of the remaining budget ---
    remaining_capacity = {cid: cluster_sizes[cid] - floor_allocation[cid] for cid in cluster_sizes}
    remaining_capacity = {cid: cap for cid, cap in remaining_capacity.items() if cap > 0}

    if not remaining_capacity:
        return floor_allocation

    total_remaining_capacity = sum(remaining_capacity.values())
    exact_shares = {cid: budget_remaining * cap / total_remaining_capacity for cid, cap in remaining_capacity.items()}
    extra_floor_shares = {cid: int(np.floor(share)) for cid, share in exact_shares.items()}
    extra_floor_shares = {cid: min(extra_floor_shares[cid], remaining_capacity[cid]) for cid in extra_floor_shares}

    allocated_extra = sum(extra_floor_shares.values())
    leftover = budget_remaining - allocated_extra

    remainder_order = sorted(
        remaining_capacity.keys(),
        key=lambda cid: (exact_shares[cid] - extra_floor_shares[cid]),
        reverse=True,
    )

    i = 0
    while leftover > 0 and i < len(remainder_order) * 3:
        cid = remainder_order[i % len(remainder_order)]
        if extra_floor_shares[cid] < remaining_capacity[cid]:
            extra_floor_shares[cid] += 1
            leftover -= 1
        i += 1

    final_allocation = dict(floor_allocation)
    for cid, extra in extra_floor_shares.items():
        final_allocation[cid] += extra

    return final_allocation


def stratified_sample(joined: dict, n_total: int, rng: np.random.Generator) -> list[str]:
    """
    Draws a stratified sample of chunk_ids, proportional to BERTopic cluster size,
    with a minimum-floor guarantee so small clusters aren't structurally excluded.
    Outlier points (cluster == -1) are excluded from the sampling population.
    """
    by_cluster: dict[int, list[str]] = {}
    for cid in joined["chunk_ids"]:
        cluster = joined["clusters"][cid]
        if cluster == -1:
            continue
        by_cluster.setdefault(cluster, []).append(cid)

    if not by_cluster:
        return []

    cluster_sizes = {cid: len(members) for cid, members in by_cluster.items()}
    allocation = compute_proportional_allocation(cluster_sizes, n_total)

    sampled = []
    for cluster_id, n_from_cluster in allocation.items():
        members = by_cluster[cluster_id]
        chosen = rng.choice(members, size=min(n_from_cluster, len(members)), replace=False)
        sampled.extend(chosen.tolist())

    return sampled

# %% [markdown]
# ### W2 pairing function (multi-hop, cluster-stratified pairs)
#
# **Defining "adjacent cluster" precisely**: BERTopic doesn't provide a built-in notion of cluster adjacency, so this needs an explicit, computable definition rather than a vague one. Here, a cluster centroid is computed as the mean embedding of its member chunks, then "adjacent" means the nearest other centroid by cosine distance. This gives every cluster exactly one well-defined adjacent cluster, computed the same way every time (reproducible), and ties directly to the embedding geometry already used everywhere else in this pipeline.
#
# **Why pairs come from the same-or-adjacent cluster, not any two random clusters**: a pair from two unrelated clusters (e.g. a cs.DB paper on query optimization paired with a cs.DB paper on distributed transactions) has no natural comparison to ask about, forcing Gemini to either fabricate a connection or produce a generic, low-quality multi-hop question. Same-cluster pairs support "how do paper A and paper B's approaches to the same sub-problem differ," and adjacent-cluster pairs support "how does paper A's approach in sub-theme X relate to or differ from paper B's approach in the neighboring sub-theme Y," both of which are answerable, genuine comparison questions, unlike a random cross-cluster pair.
#
# **Stratification for W2**: 50 pairs are allocated across clusters proportionally to cluster size, same logic as W1/W3, so the topical distribution of W2's pair-sources also mirrors the category's population, not just W1 and W3's single-chunk pools.
#
# **Pair composition**: for each allocated cluster, roughly half its pairs are same-cluster (two different chunks from that cluster) and half are cross-cluster (one chunk from that cluster, one from its nearest adjacent cluster), giving a mix of "compare two takes on the same sub-topic" and "compare two related-but-distinct sub-topics" questions, rather than only one pairing style.

# %%
def compute_cluster_centroids(joined: dict) -> dict[int, np.ndarray]:
    """Mean embedding per cluster, excluding outliers (-1)."""
    by_cluster: dict[int, list[np.ndarray]] = {}
    for cid in joined["chunk_ids"]:
        cluster = joined["clusters"][cid]
        if cluster == -1:
            continue
        by_cluster.setdefault(cluster, []).append(joined["embeddings"][cid])

    centroids = {}
    for cluster_id, vectors in by_cluster.items():
        stacked = np.stack(vectors)
        centroid = stacked.mean(axis=0)
        centroid = centroid / (np.linalg.norm(centroid) + 1e-8)  # normalize for cosine comparison
        centroids[cluster_id] = centroid
    return centroids


def find_nearest_adjacent_cluster(cluster_id: int, centroids: dict[int, np.ndarray]) -> int | None:
    """Returns the cluster_id of the nearest OTHER cluster centroid by cosine distance, or None if only one cluster exists."""
    other_ids = [cid for cid in centroids if cid != cluster_id]
    if not other_ids:
        return None

    this_centroid = centroids[cluster_id]
    similarities = {cid: float(np.dot(this_centroid, centroids[cid])) for cid in other_ids}
    return max(similarities, key=similarities.get)  # highest cosine similarity = nearest


def stratified_pair_sample(joined: dict, n_pairs: int, rng: np.random.Generator) -> list[tuple[str, str, str]]:
    """
    Draws n_pairs stratified chunk-id pairs for W2.
    Returns a list of (chunk_id_a, chunk_id_b, pair_type) tuples, where pair_type
    is 'same_cluster' or 'adjacent_cluster', kept for transparency in the output CSV.
    """
    by_cluster: dict[int, list[str]] = {}
    for cid in joined["chunk_ids"]:
        cluster = joined["clusters"][cid]
        if cluster == -1:
            continue
        by_cluster.setdefault(cluster, []).append(cid)

    # only clusters with 2+ members can supply a same-cluster pair or serve as a pair anchor
    eligible_clusters = {cid: members for cid, members in by_cluster.items() if len(members) >= 2}
    if not eligible_clusters:
        return []

    centroids = compute_cluster_centroids(joined)
    cluster_sizes = {cid: len(members) for cid, members in eligible_clusters.items()}
    allocation = compute_proportional_allocation(cluster_sizes, n_pairs)

    pairs = []
    for cluster_id, n_from_cluster in allocation.items():
        members = eligible_clusters[cluster_id]
        n_same = n_from_cluster // 2
        n_adjacent = n_from_cluster - n_same

        for _ in range(n_same):
            if len(members) < 2:
                break
            a, b = rng.choice(members, size=2, replace=False)
            pairs.append((a, b, "same_cluster"))

        adjacent_id = find_nearest_adjacent_cluster(cluster_id, centroids)
        if adjacent_id is not None and adjacent_id in by_cluster:
            adjacent_members = by_cluster[adjacent_id]
            for _ in range(n_adjacent):
                a = rng.choice(members)
                b = rng.choice(adjacent_members)
                pairs.append((str(a), str(b), "adjacent_cluster"))

    return pairs[:n_pairs]  # trim in case allocation produced a few extra from rounding

# %% [markdown]
# ### Run sampling across all categories and both corpus types
#
# Categories missing any of the three required artifacts (source, embeddings, clusters) are skipped and reported, not treated as an error, expected for categories not yet fully processed through the pipeline. A single `rng` (seeded once) is threaded through every draw, not re-seeded per category, so the full sequence of random draws across the whole run is reproducible end to end, not just reproducible category by category in isolation.

# %%
rng = np.random.default_rng(RANDOM_STATE)

all_samples = {}   # {(corpus_type, category, workload): sample data}
skipped = []

for corpus_type in ["abstracts", "pdf_chunks"]:
    for category in ALL_CATEGORIES:
        print(f"\n=== {corpus_type} / {category} ===")

        joined = build_joined_table(category, corpus_type)
        if joined is None:
            print(f"  [SKIP] missing source/embeddings/clusters, not yet processed")
            skipped.append((corpus_type, category))
            continue

        total_chunks = len(joined["chunk_ids"])
        n_outliers = sum(1 for cid in joined["chunk_ids"] if joined["clusters"][cid] == -1)
        print(f"  {total_chunks} chunks total, {n_outliers} outliers ({100*n_outliers/total_chunks:.1f}%) excluded from sampling")

        w1_sample = stratified_sample(joined, N_PER_WORKLOAD, rng)
        w3_sample = stratified_sample(joined, N_PER_WORKLOAD, rng)
        w2_pairs = stratified_pair_sample(joined, N_PER_WORKLOAD, rng)

        print(f"  W1: {len(w1_sample)}/{N_PER_WORKLOAD} sampled")
        print(f"  W2: {len(w2_pairs)}/{N_PER_WORKLOAD} pairs sampled")
        print(f"  W3: {len(w3_sample)}/{N_PER_WORKLOAD} sampled")

        all_samples[(corpus_type, category, "w1")] = {"chunk_ids": w1_sample, "joined": joined}
        all_samples[(corpus_type, category, "w3")] = {"chunk_ids": w3_sample, "joined": joined}
        all_samples[(corpus_type, category, "w2")] = {"pairs": w2_pairs, "joined": joined}

print(f"\n\nSkipped (missing artifacts): {skipped if skipped else 'none'}")
# Out:
# === abstracts / cs.AI ===
#   7369 chunks total, 2082 outliers (28.3%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === abstracts / cs.LG ===
#   10746 chunks total, 1923 outliers (17.9%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === abstracts / cs.IR ===
#   3076 chunks total, 528 outliers (17.2%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === abstracts / cs.DB ===
#   1532 chunks total, 398 outliers (26.0%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === abstracts / cs.SE ===
#   2281 chunks total, 308 outliers (13.5%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === abstracts / cs.CV ===
#   14163 chunks total, 3775 outliers (26.7%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === abstracts / cs.CL ===
#   12418 chunks total, 3071 outliers (24.7%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === abstracts / cs.NE ===
#   1501 chunks total, 224 outliers (14.9%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === abstracts / cs.DC ===
#   1517 chunks total, 301 outliers (19.8%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === abstracts / cs.CR ===
#   1523 chunks total, 67 outliers (4.4%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === pdf_chunks / cs.AI ===
#   2060 chunks total, 392 outliers (19.0%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === pdf_chunks / cs.LG ===
#   1937 chunks total, 516 outliers (26.6%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === pdf_chunks / cs.IR ===
#   1371 chunks total, 305 outliers (22.2%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === pdf_chunks / cs.DB ===
#   1768 chunks total, 408 outliers (23.1%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === pdf_chunks / cs.SE ===
#   1956 chunks total, 487 outliers (24.9%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === pdf_chunks / cs.CV ===
#   1250 chunks total, 342 outliers (27.4%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === pdf_chunks / cs.CL ===
#   1363 chunks total, 300 outliers (22.0%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === pdf_chunks / cs.NE ===
#   1668 chunks total, 406 outliers (24.3%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === pdf_chunks / cs.DC ===
#   1826 chunks total, 341 outliers (18.7%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
# === pdf_chunks / cs.CR ===
#   1517 chunks total, 387 outliers (25.5%) excluded from sampling
#   W1: 50/50 sampled
#   W2: 50/50 pairs sampled
#   W3: 50/50 sampled
#
#
# Skipped (missing artifacts): none

# %% [markdown]
# ### Diagnostic: cluster count and size distribution per category
#
# **Why this diagnostic, given the observed TVD results**: several categories showed high total variation distance (cs.CV abstracts 0.51, cs.CL abstracts 0.45, cs.AI abstracts 0.37, cs.LG abstracts 0.36), while others were well under 0.1. TVD by itself doesn't say *why* a category diverged, it could be a bug, or it could be an inherent consequence of cluster structure interacting with integer-rounding allocation (as flagged in the `compute_proportional_allocation` reasoning above: many small clusters relative to a 50-sample budget forces larger rounding error). This cell reports, per category, the number of BERTopic clusters (excluding outliers) and the coefficient of variation of cluster sizes (std / mean, a scale-free measure of how uneven cluster sizes are), so the actual cause can be confirmed before changing any sampling logic.
#
# **Why coefficient of variation specifically**: raw standard deviation of cluster size isn't comparable across categories with different total populations (a category with 5,000 chunks naturally has larger absolute cluster sizes than one with 500). Coefficient of variation normalizes by the mean, making "how uneven are this category's clusters" comparable across categories of very different scale, which is exactly what's needed to see whether the high-TVD categories share a common structural trait (e.g. many small clusters, or one dominant cluster plus several tiny ones) versus the low-TVD categories.

# %%
import pandas as pd
diagnostic_rows = []

for (corpus_type, category, workload), data in all_samples.items():
    if workload != "w1":  # w1 and w3 share the same joined population, only need one pass
        continue

    joined = data["joined"]
    by_cluster: dict[int, int] = {}
    for cid in joined["chunk_ids"]:
        cluster = joined["clusters"][cid]
        if cluster == -1:
            continue
        by_cluster[cluster] = by_cluster.get(cluster, 0) + 1

    sizes = np.array(list(by_cluster.values()))
    n_clusters = len(sizes)
    mean_size = sizes.mean() if n_clusters else 0
    cv = (sizes.std() / mean_size) if mean_size > 0 else 0

    # how many clusters would get 0 samples under proportional allocation at n_total=50
    total_pop = sizes.sum()
    exact_shares = 50 * sizes / total_pop if total_pop > 0 else np.array([])
    n_clusters_rounding_to_zero = int(np.sum(exact_shares < 0.5)) if len(exact_shares) else 0

    diagnostic_rows.append({
        "corpus_type": corpus_type,
        "category": category,
        "n_clusters": n_clusters,
        "population_size": int(total_pop),
        "mean_cluster_size": round(mean_size, 1),
        "min_cluster_size": int(sizes.min()) if n_clusters else 0,
        "max_cluster_size": int(sizes.max()) if n_clusters else 0,
        "cluster_size_cv": round(cv, 3),
        "n_clusters_undersized_for_n50": n_clusters_rounding_to_zero,
    })

diagnostic_df = pd.DataFrame(diagnostic_rows).sort_values("cluster_size_cv", ascending=False)
print("Sorted by cluster size unevenness (coefficient of variation), highest first:\n")
diagnostic_df
# Out:
# Sorted by cluster size unevenness (coefficient of variation), highest first:
#    corpus_type category  n_clusters  population_size  mean_cluster_size  \
# 2    abstracts    cs.IR          13             2548              196.0
# 7    abstracts    cs.NE          10             1277              127.7
# 4    abstracts    cs.SE          13             1973              151.8
# 9    abstracts    cs.CR           8             1456              182.0
# 1    abstracts    cs.LG          30             8823              294.1
# 11  pdf_chunks    cs.LG          15             1421               94.7
# 13  pdf_chunks    cs.DB          23             1360               59.1
# 6    abstracts    cs.CL          40             9347              233.7
# 0    abstracts    cs.AI          36             5287              146.9
# 15  pdf_chunks    cs.CV          15              908               60.5
# 5    abstracts    cs.CV          55            10388              188.9
# 18  pdf_chunks    cs.DC          19             1485               78.2
# 10  pdf_chunks    cs.AI          17             1668               98.1
# 14  pdf_chunks    cs.SE          22             1469               66.8
# 17  pdf_chunks    cs.NE          22             1262               57.4
# 16  pdf_chunks    cs.CL          19             1063               55.9
# 3    abstracts    cs.DB          18             1134               63.0
# 19  pdf_chunks    cs.CR          16             1130               70.6
# 8    abstracts    cs.DC          11             1216              110.5
# 12  pdf_chunks    cs.IR          17             1066               62.7
#
#     min_cluster_size  max_cluster_size  cluster_size_cv  \
# 2                 33              1345            1.753
# 7                 30               741            1.610
# 4                 52               862            1.377
# 9                 34               768            1.246
# 1                 82              1984            1.237
# 11                50               383            0.853
# 13                30               252            0.842
# 6                 81               841            0.837
# 0                 53               636            0.758
# 15                30               220            0.756
# 5                 81               687            0.692
# 18                31               210            0.665
# 10                51               329            0.642
# 14                30               187            0.607
# 17                31               157            0.572
# 16                31               127            0.538
# 3                 31               129            0.512
# 19                30               120            0.411
# 8                 59               204            0.401
# 12                30               114            0.390
#
#     n_clusters_undersized_for_n50
# 2                               0
# 7                               0
# 4                               0
# 9                               0
# 1                               1
# 11                              0
# 13                              0
# 6                               5
# 0                               0
# 15                              0
# 5                              17
# 18                              0
# 10                              0
# 14                              0
# 17                              0
# 16                              0
# 3                               0
# 19                              0
# 8                               0
# 12                              0

# %% [markdown]
# ### Export CSVs
#
# **W1/W3 CSV columns**: `chunk_id`, `category`, `bertopic_cluster`, `text` (or `title` for abstracts), so the CSV is directly usable as input to the next stage (Gemini query generation) without needing to re-join against the Hub.
#
# **W2 CSV columns**: `pair_id`, `category`, `chunk_id_a`, `chunk_id_b`, `pair_type` (same_cluster / adjacent_cluster), `cluster_a`, `cluster_b`, plus both chunks' text, so a downstream query-generation script has everything needed to prompt for a comparison question without any additional lookups.

# %%
import pandas as pd


def get_display_text(record: dict, corpus_type: str) -> str:
    return record["text"]


def get_display_title(record: dict, corpus_type: str) -> str:
    if corpus_type == "abstracts":
        return record.get("title", "")
    return ""  # PDF chunks have no title field


csv_paths = {}

for (corpus_type, category, workload), data in all_samples.items():
    out_path = os.path.join(SAMPLES_DIR, corpus_type, workload, f"{category}.csv")

    if os.path.exists(out_path) and not FORCE_RESAMPLE:
        print(f"[SKIP] {corpus_type}/{workload}/{category}: already exists at {out_path}")
        csv_paths[(corpus_type, category, workload)] = out_path
        continue

    joined = data["joined"]

    if workload in ("w1", "w3"):
        rows = []
        for cid in data["chunk_ids"]:
            record = joined["source"][cid]
            rows.append({
                "chunk_id": cid,
                "category": category,
                "bertopic_cluster": joined["clusters"][cid],
                "title": get_display_title(record, corpus_type),
                "text": get_display_text(record, corpus_type),
            })
        df = pd.DataFrame(rows)

    else:  # w2
        rows = []
        for i, (cid_a, cid_b, pair_type) in enumerate(data["pairs"]):
            record_a = joined["source"][cid_a]
            record_b = joined["source"][cid_b]
            rows.append({
                "pair_id": f"{category}_w2_{i:03d}",
                "category": category,
                "pair_type": pair_type,
                "chunk_id_a": cid_a,
                "cluster_a": joined["clusters"][cid_a],
                "title_a": get_display_title(record_a, corpus_type),
                "text_a": get_display_text(record_a, corpus_type),
                "chunk_id_b": cid_b,
                "cluster_b": joined["clusters"][cid_b],
                "title_b": get_display_title(record_b, corpus_type),
                "text_b": get_display_text(record_b, corpus_type),
            })
        df = pd.DataFrame(rows)

    df.to_csv(out_path, index=False)
    csv_paths[(corpus_type, category, workload)] = out_path
    print(f"Saved {out_path} ({len(df)} rows)")
# Out:
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w1\cs.AI.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w3\cs.AI.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w2\cs.AI.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w1\cs.LG.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w3\cs.LG.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w2\cs.LG.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w1\cs.IR.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w3\cs.IR.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w2\cs.IR.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w1\cs.DB.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w3\cs.DB.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w2\cs.DB.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w1\cs.SE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w3\cs.SE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w2\cs.SE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w1\cs.CV.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w3\cs.CV.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w2\cs.CV.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w1\cs.CL.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w3\cs.CL.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w2\cs.CL.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w1\cs.NE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w3\cs.NE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w2\cs.NE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w1\cs.DC.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w3\cs.DC.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w2\cs.DC.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w1\cs.CR.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w3\cs.CR.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\abstracts\w2\cs.CR.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w1\cs.AI.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w3\cs.AI.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w2\cs.AI.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w1\cs.LG.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w3\cs.LG.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w2\cs.LG.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w1\cs.IR.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w3\cs.IR.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w2\cs.IR.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w1\cs.DB.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w3\cs.DB.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w2\cs.DB.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w1\cs.SE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w3\cs.SE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w2\cs.SE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w1\cs.CV.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w3\cs.CV.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w2\cs.CV.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w1\cs.CL.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w3\cs.CL.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w2\cs.CL.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w1\cs.NE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w3\cs.NE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w2\cs.NE.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w1\cs.DC.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w3\cs.DC.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w2\cs.DC.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w1\cs.CR.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w3\cs.CR.csv (50 rows)
# Saved ..\data\query_samples\text-embedding-3-small\pdf_chunks\w2\cs.CR.csv (50 rows)

# %% [markdown]
# ### Figure: sample representativeness (population vs sample cluster proportions)
#
# **Why this specific figure, not just a sample-size bar chart**: the entire justification for stratified-by-cluster sampling was "the sample's topical composition should mirror the population's topical composition." A figure showing sample counts alone doesn't demonstrate that claim, it just shows how many were sampled. This figure instead plots population proportion vs sample proportion side by side per cluster, so a reader (or your supervisor) can visually verify the stratification actually worked, rather than taking the methodology's correctness on faith. A well-executed stratified sample should show the two bars closely matching for every cluster; any visible mismatch would itself be a useful diagnostic (e.g. a cluster too small to hit its exact proportional share after integer rounding).
#
# **One figure per category, per corpus type, per workload type**: kept separate rather than combined into one mega-figure, since W1 and W3 are drawn independently and could show slightly different sampled compositions by chance even though they use the same allocation logic, worth being able to inspect each draw individually rather than averaging away real differences between them.

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({
    "font.size": 8,
    "font.family": "serif",
    "axes.titlesize": 9,
    "axes.labelsize": 8,
    "xtick.labelsize": 7,
    "ytick.labelsize": 7,
    "legend.fontsize": 7,
})


def plot_representativeness(joined: dict, sampled_chunk_ids: list[str], corpus_type: str, category: str, workload: str, out_path: str) -> None:
    population_by_cluster: dict[int, int] = {}
    for cid in joined["chunk_ids"]:
        cluster = joined["clusters"][cid]
        if cluster == -1:
            continue
        population_by_cluster[cluster] = population_by_cluster.get(cluster, 0) + 1

    sample_by_cluster: dict[int, int] = {}
    for cid in sampled_chunk_ids:
        cluster = joined["clusters"][cid]
        sample_by_cluster[cluster] = sample_by_cluster.get(cluster, 0) + 1

    clusters = sorted(population_by_cluster.keys())
    pop_total = sum(population_by_cluster.values())
    sample_total = sum(sample_by_cluster.values()) or 1

    pop_pct = [100 * population_by_cluster[c] / pop_total for c in clusters]
    sample_pct = [100 * sample_by_cluster.get(c, 0) / sample_total for c in clusters]

    x = np.arange(len(clusters))
    width = 0.38

    fig, ax = plt.subplots(figsize=(IEEE_COLUMN_WIDTH_INCHES, 2.2))
    ax.bar(x - width/2, pop_pct, width, label="Population %", color="#4C72B0")
    ax.bar(x + width/2, sample_pct, width, label="Sample %", color="#DD8452")

    ax.set_xlabel("BERTopic cluster")
    ax.set_ylabel("% of chunks")
    ax.set_title(f"{category} ({corpus_type}, {workload.upper()}): population vs sample")
    ax.set_xticks(x)
    ax.set_xticklabels([f"T{c}" for c in clusters])
    ax.legend()
    ax.grid(alpha=0.25, axis="y")

    fig.tight_layout()
    fig.savefig(out_path, dpi=IEEE_FIGURE_DPI, bbox_inches="tight")
    plt.close(fig)

# %% [markdown]
# ### Generate per-category representativeness figures
#
# Runs for all three workload types. For W1 and W3 (single-chunk pools), cluster membership is read directly per sampled chunk_id. For W2 (pairs), each pair contributes both its chunk_id_a and chunk_id_b to the flattened membership count, since a pair "represents" both of its anchor clusters, this reuses the exact same `plot_representativeness` function rather than a separate implementation, since the underlying comparison (population cluster proportions vs. sampled cluster proportions) is identical once pairs are flattened into a chunk_id list.

# %%
for (corpus_type, category, workload), data in all_samples.items():
    fig_path = os.path.join(FIGURES_DIR, f"{corpus_type}_{category}_{workload}_representativeness.png")
    if os.path.exists(fig_path) and not FORCE_RESAMPLE:
        print(f"[SKIP] {fig_path} already exists")
        continue

    if workload == "w2":
        flattened_chunk_ids = [cid for pair in data["pairs"] for cid in (pair[0], pair[1])]
    else:
        flattened_chunk_ids = data["chunk_ids"]

    plot_representativeness(data["joined"], flattened_chunk_ids, corpus_type, category, workload, fig_path)
    print(f"Saved {fig_path}")
# Out:
# Saved ..\results\figures\sampling\abstracts_cs.AI_w1_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.AI_w3_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.AI_w2_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.LG_w1_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.LG_w3_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.LG_w2_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.IR_w1_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.IR_w3_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.IR_w2_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.DB_w1_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.DB_w3_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.DB_w2_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.SE_w1_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.SE_w3_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.SE_w2_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.CV_w1_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.CV_w3_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.CV_w2_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.CL_w1_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.CL_w3_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.CL_w2_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.NE_w1_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.NE_w3_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.NE_w2_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.DC_w1_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.DC_w3_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.DC_w2_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.CR_w1_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.CR_w3_representativeness.png
# Saved ..\results\figures\sampling\abstracts_cs.CR_w2_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.AI_w1_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.AI_w3_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.AI_w2_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.LG_w1_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.LG_w3_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.LG_w2_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.IR_w1_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.IR_w3_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.IR_w2_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.DB_w1_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.DB_w3_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.DB_w2_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.SE_w1_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.SE_w3_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.SE_w2_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.CV_w1_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.CV_w3_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.CV_w2_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.CL_w1_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.CL_w3_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.CL_w2_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.NE_w1_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.NE_w3_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.NE_w2_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.DC_w1_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.DC_w3_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.DC_w2_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.CR_w1_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.CR_w3_representativeness.png
# Saved ..\results\figures\sampling\pdf_chunks_cs.CR_w2_representativeness.png

# %% [markdown]
# ### Cross-category summary figure: sampling coverage overview
#
# **Why this figure**: individual per-category, per-workload representativeness plots (above) are the rigorous, granular evidence, but a reader (or a supervisor skimming the paper) benefits from one consolidated view showing sample coverage across all 10 categories and all three workload types at once. This figure reports, per category and workload type, the **total variation distance** between the population's cluster-proportion distribution and the sample's cluster-proportion distribution, a single number in [0, 1] where 0 means the sample's topical composition perfectly matches the population's, and higher values indicate more divergence. This is the standard way to compress a full distributional comparison (like the bar-pair plots above) into one comparable number across many categories, rather than requiring 30 separate bar charts to be read side by side.
#
# **Total variation distance formula**: TVD = 0.5 * sum(|population_proportion_c - sample_proportion_c|) over all clusters c. Bounded in [0, 1]. This is computed directly from the same population/sample cluster counts used in the per-category bar charts, so the summary figure and the detailed figures are guaranteed to tell a consistent story, not two independently-computed metrics that could disagree.
#
# **W2 is included here too**: each W2 pair is flattened into its two constituent chunk_ids before computing membership counts, so a category's 50 pairs contribute 100 chunk_id memberships toward the sample-side distribution. This was previously missing from this cell, an oversight, W2's sampling representativeness needs the same empirical check as W1/W3, not a silent exemption from it.

# %%
def total_variation_distance(joined: dict, sampled_chunk_ids: list[str]) -> float:
    population_by_cluster: dict[int, int] = {}
    for cid in joined["chunk_ids"]:
        cluster = joined["clusters"][cid]
        if cluster == -1:
            continue
        population_by_cluster[cluster] = population_by_cluster.get(cluster, 0) + 1

    sample_by_cluster: dict[int, int] = {}
    for cid in sampled_chunk_ids:
        cluster = joined["clusters"][cid]
        sample_by_cluster[cluster] = sample_by_cluster.get(cluster, 0) + 1

    pop_total = sum(population_by_cluster.values())
    sample_total = sum(sample_by_cluster.values()) or 1

    all_clusters = set(population_by_cluster) | set(sample_by_cluster)
    tvd = 0.5 * sum(
        abs(population_by_cluster.get(c, 0) / pop_total - sample_by_cluster.get(c, 0) / sample_total)
        for c in all_clusters
    )
    return tvd


tvd_rows = []
for (corpus_type, category, workload), data in all_samples.items():
    if workload == "w2":
        flattened_chunk_ids = [cid for pair in data["pairs"] for cid in (pair[0], pair[1])]
    else:
        flattened_chunk_ids = data["chunk_ids"]

    tvd = total_variation_distance(data["joined"], flattened_chunk_ids)
    tvd_rows.append({"corpus_type": corpus_type, "category": category, "workload": workload, "tvd": tvd})

tvd_df = pd.DataFrame(tvd_rows)

tvd_csv_path = os.path.join(SAMPLES_DIR, "sampling_representativeness_tvd.csv")
tvd_df.to_csv(tvd_csv_path, index=False)
print(f"Saved {tvd_csv_path}")
tvd_df
# Out:
# Saved ..\data\query_samples\text-embedding-3-small\sampling_representativeness_tvd.csv
#    corpus_type category workload       tvd
# 0    abstracts    cs.AI       w1  0.139913
# 1    abstracts    cs.AI       w3  0.139913
# 2    abstracts    cs.AI       w2  0.206558
# 3    abstracts    cs.LG       w1  0.192359
# 4    abstracts    cs.LG       w3  0.192359
# 5    abstracts    cs.LG       w2  0.255882
# 6    abstracts    cs.IR       w1  0.139812
# 7    abstracts    cs.IR       w3  0.139812
# 8    abstracts    cs.IR       w2  0.203046
# 9    abstracts    cs.DB       w1  0.092628
# 10   abstracts    cs.DB       w3  0.092628
# 11   abstracts    cs.DB       w2  0.176949
# 12   abstracts    cs.SE       w1  0.105362
# 13   abstracts    cs.SE       w3  0.105362
# 14   abstracts    cs.SE       w2  0.184703
# 15   abstracts    cs.CV       w1  0.252514
# 16   abstracts    cs.CV       w3  0.252514
# 17   abstracts    cs.CV       w2  0.306758
# 18   abstracts    cs.CL       w1  0.209381
# 19   abstracts    cs.CL       w3  0.209381
# 20   abstracts    cs.CL       w2  0.271131
# 21   abstracts    cs.NE       w1  0.080266
# 22   abstracts    cs.NE       w3  0.080266
# 23   abstracts    cs.NE       w2  0.243743
# 24   abstracts    cs.DC       w1  0.031875
# 25   abstracts    cs.DC       w3  0.031875
# 26   abstracts    cs.DC       w2  0.111184
# 27   abstracts    cs.CR       w1  0.067582
# 28   abstracts    cs.CR       w3  0.067582
# 29   abstracts    cs.CR       w2  0.174341
# 30  pdf_chunks    cs.AI       w1  0.071727
# 31  pdf_chunks    cs.AI       w3  0.071727
# 32  pdf_chunks    cs.AI       w2  0.161055
# 33  pdf_chunks    cs.LG       w1  0.070837
# 34  pdf_chunks    cs.LG       w3  0.070837
# 35  pdf_chunks    cs.LG       w2  0.192512
# 36  pdf_chunks    cs.IR       w1  0.068780
# 37  pdf_chunks    cs.IR       w3  0.068780
# 38  pdf_chunks    cs.IR       w2  0.164690
# 39  pdf_chunks    cs.DB       w1  0.146765
# 40  pdf_chunks    cs.DB       w3  0.146765
# 41  pdf_chunks    cs.DB       w2  0.122206
# 42  pdf_chunks    cs.SE       w1  0.126698
# 43  pdf_chunks    cs.SE       w3  0.126698
# 44  pdf_chunks    cs.SE       w2  0.183247
# 45  pdf_chunks    cs.CV       w1  0.061322
# 46  pdf_chunks    cs.CV       w3  0.061322
# 47  pdf_chunks    cs.CV       w2  0.116344
# 48  pdf_chunks    cs.CL       w1  0.086077
# 49  pdf_chunks    cs.CL       w3  0.086077
# 50  pdf_chunks    cs.CL       w2  0.150536
# 51  pdf_chunks    cs.NE       w1  0.145166
# 52  pdf_chunks    cs.NE       w3  0.145166
# 53  pdf_chunks    cs.NE       w2  0.093090
# 54  pdf_chunks    cs.DC       w1  0.129024
# 55  pdf_chunks    cs.DC       w3  0.129024
# 56  pdf_chunks    cs.DC       w2  0.105354
# 57  pdf_chunks    cs.CR       w1  0.065841
# 58  pdf_chunks    cs.CR       w3  0.065841
# 59  pdf_chunks    cs.CR       w2  0.113009

# %% [markdown]
# ### Grand summary figure: TVD across all categories and workload types
#
# One double-column-width figure for the paper: grouped bars, one group per category, W1/W2/W3 TVD side by side within each group, all 10 categories and all three workload types in one frame. This is the figure that directly answers "does the stratified sampling actually represent the population," across the entire corpus and every workload type, in one glance, backed by the per-category detail figures and the raw CSV for anyone who wants to verify a specific category more closely.

# %%
plt.rcParams.update({
    "font.size": 9,
    "font.family": "serif",
    "axes.titlesize": 11,
    "axes.labelsize": 9,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "legend.fontsize": 8,
})

for corpus_type in ["abstracts", "pdf_chunks"]:
    subset = tvd_df[tvd_df["corpus_type"] == corpus_type]
    if subset.empty:
        continue

    categories_present = [c for c in ALL_CATEGORIES if c in subset["category"].values]

    def get_vals(workload):
        return [
            subset[(subset["category"] == c) & (subset["workload"] == workload)]["tvd"].values[0]
            if not subset[(subset["category"] == c) & (subset["workload"] == workload)].empty else 0
            for c in categories_present
        ]

    w1_vals = get_vals("w1")
    w2_vals = get_vals("w2")
    w3_vals = get_vals("w3")

    x = np.arange(len(categories_present))
    width = 0.26

    fig, ax = plt.subplots(figsize=(IEEE_FULL_WIDTH_INCHES, 3.0))
    ax.bar(x - width, w1_vals, width, label="W1 sample", color="#4C72B0")
    ax.bar(x, w2_vals, width, label="W2 sample (pairs, flattened)", color="#C44E52")
    ax.bar(x + width, w3_vals, width, label="W3 sample", color="#55A868")

    ax.axhline(0.1, color="gray", linestyle="--", linewidth=0.8, label="TVD=0.1 reference")

    ax.set_xlabel("Category")
    ax.set_ylabel("Total variation distance\n(population vs sample)")
    ax.set_title(f"Stratified sampling representativeness across categories ({corpus_type})")
    ax.set_xticks(x)
    ax.set_xticklabels(categories_present, rotation=30, ha="right")
    all_vals = w1_vals + w2_vals + w3_vals
    ax.set_ylim(0, (max(all_vals) if all_vals else 0.1) * 1.3 + 0.02)
    ax.legend()
    ax.grid(alpha=0.25, axis="y")

    fig.tight_layout()
    grand_fig_path = os.path.join(FIGURES_DIR, f"grand_summary_tvd_{corpus_type}.png")
    fig.savefig(grand_fig_path, dpi=IEEE_FIGURE_DPI, bbox_inches="tight")
    plt.show()
    print(f"Saved {grand_fig_path}")
# Out:
# Saved ..\results\figures\sampling\grand_summary_tvd_abstracts.png
# Saved ..\results\figures\sampling\grand_summary_tvd_pdf_chunks.png

# %% [markdown]
# ### Upload samples and results back to Hugging Face
#
# CSVs (the actual query-generation input) go to the Hub. Figures stay local, they belong in the paper/repo, not the shared dataset.

# %%
from huggingface_hub import HfApi

api = HfApi()

for (corpus_type, category, workload), local_path in csv_paths.items():
    repo_path = f"query_samples/{EMBEDDING_MODEL}/{corpus_type}/{workload}/{category}.csv"
    api.upload_file(
        path_or_fileobj=local_path,
        path_in_repo=repo_path,
        repo_id=REPO_ID,
        repo_type=REPO_TYPE,
        commit_message=f"Upload {workload} query samples for {corpus_type}/{category} (by {user_info['name']})",
    )
    print(f"Uploaded {repo_path}")

api.upload_file(
    path_or_fileobj=tvd_csv_path,
    path_in_repo=f"query_samples/{EMBEDDING_MODEL}/sampling_representativeness_tvd.csv",
    repo_id=REPO_ID,
    repo_type=REPO_TYPE,
    commit_message=f"Upload sampling representativeness TVD summary (by {user_info['name']})",
)
print("Uploaded TVD summary")
# Out:
# Uploaded query_samples/text-embedding-3-small/abstracts/w1/cs.AI.csv
# Uploaded query_samples/text-embedding-3-small/abstracts/w3/cs.AI.csv
# Uploaded query_samples/text-embedding-3-small/abstracts/w2/cs.AI.csv
# Uploaded query_samples/text-embedding-3-small/abstracts/w1/cs.LG.csv
# Uploaded query_samples/text-embedding-3-small/abstracts/w3/cs.LG.csv
# Uploaded query_samples/text-embedding-3-small/abstracts/w2/cs.LG.csv

# %% [markdown]
# ### Reading the result
#
# - A low TVD (roughly under 0.1, the reference line in the grand summary figure) means the stratified sample's topical composition closely tracks the population's, direct empirical support for "this sample represents the entire population," not just an assertion.
# - Categories with a visibly higher TVD are worth a closer look at their individual representativeness bar chart, likely caused by a small number of clusters where integer rounding pushed the sample noticeably off the exact proportional target, especially likely for categories with very small or very numerous clusters.
# - `data/query_samples/<model>/<corpus_type>/<workload>/<category>.csv` is the direct input for the next pipeline stage (Gemini query generation), each row already carries the text needed to prompt for a question, no further lookups required.
